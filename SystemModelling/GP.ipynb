# %%
# !python gp_narx_task41_solution.py --project-root . --na 5 --nb 5 --max-train-samples 2000
# Out:
# Using benchmark directory:
# /gpfs/home4/scur2879/DesignProject/SystemModelling/gym-unbalanced-disk/disc-benchmark-files
# Traceback (most recent call last):
#   File "/gpfs/home4/scur2879/DesignProject/SystemModelling/gp_narx_task41_solution.py", line 439, in <module>
#     main()
#   File "/gpfs/home4/scur2879/DesignProject/SystemModelling/gp_narx_task41_solution.py", line 315, in main
#     train_data = np.load(train_path)
#   File "/home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/numpy/lib/_npyio_impl.py", line 455, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '/gpfs/home4/scur2879/DesignProject/SystemModelling/gym-unbalanced-disk/disc-benchmark-files/training-val-test-data.npz'

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 5 --nb 5 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 3 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 5 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 7 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 6 --nb 6 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !!python SystemModelling/gp_narx_task41_solution.py --project-root . --na 10 --nb 10 --max-train-samples 2000
# Out:
# ["python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory"]

# %%
# !python SystemModelling/gp_narx_task41_solution.py --project-root . --na 7 --nb 7 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory
