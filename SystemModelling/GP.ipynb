# %%
# %ls
# Out:
# DesignProject.ipynb  GP.ipynb  SystemModelling/  gp_narx_task41_solution.py

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 5 --nb 5 --max-train-samples 2000
# Out:
# Using benchmark directory:
# /gpfs/home4/scur2879/DesignProject/gym-unbalanced-disk/disc-benchmark-files
#
# Loaded training data
# u shape : (35000,)
# th shape: (35000,)
#
# Training GP-NARX with na=5, nb=5
# Total NARX samples: 27995
# Samples used for GP training: 2000
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 3 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 5 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 7 --nb 3 --max-train-samples 2000
# Out:
# python: can't open file '/gpfs/home4/scur2879/DesignProject/SystemModelling/SystemModelling/gp_narx_task41_solution.py': [Errno 2] No such file or directory

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 6 --nb 6 --max-train-samples 2000
# Out:
# Using benchmark directory:
# /gpfs/home4/scur2879/DesignProject/gym-unbalanced-disk/disc-benchmark-files
#
# Loaded training data
# u shape : (35000,)
# th shape: (35000,)
#
# Training GP-NARX with na=6, nb=6
# Total NARX samples: 27994
# Samples used for GP training: 2000
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 10 --nb 10 --max-train-samples 2000
# Out:
# Using benchmark directory:
# /gpfs/home4/scur2879/DesignProject/gym-unbalanced-disk/disc-benchmark-files
#
# Loaded training data
# u shape : (35000,)
# th shape: (35000,)
#
# Training GP-NARX with na=10, nb=10
# Total NARX samples: 27990
# Samples used for GP training: 2000
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
# !python gp_narx_task41_solution.py --project-root .. --na 7 --nb 7 --max-train-samples 2000
# Out:
# Using benchmark directory:
# /gpfs/home4/scur2879/DesignProject/gym-unbalanced-disk/disc-benchmark-files
#
# Loaded training data
# u shape : (35000,)
# th shape: (35000,)
#
# Training GP-NARX with na=7, nb=7
# Total NARX samples: 27993
# Samples used for GP training: 2000
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/scur2879/DesignProject/.venv/lib64/python3.9/site-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...
